# %%
def oz(value, n=2):
    for i in range(n):
        print(value)

oz("일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.")
# Out:
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.

# %%
def oz(value, n=2):
    for i in range(n):
        print(value)

oz("일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.", n=10)
# Out:
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.
# 일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.

# %%
# 기본 매개변수 뒤에는 일반 매개 변수가 올 수 없다
def oz(n=2 ,value):
    for i in range(n):
        print(value)

oz("일반 매개변수 다음에 기본 매개변수를 배치해야 합니다.")
# Out:
#   File "<ipython-input-5-d95b069194f1>", line 1
#     def oz(n=2 ,value):
#                 ^
# SyntaxError: non-default argument follows default argument
