# %%
def oz_return():
    print("파이썬")
    print("재미있엉")
    return
    print("거짓말하네")

oz_return()
# Out:
# 파이썬
# 재미있엉

# %%
# 값과 함께 리턴하는 경우
def oz_return():
    return "파이썬 재미있엉"

result= oz_return()
print(result)

oz_return()
# Out:
# 파이썬 재미있엉
# '파이썬 재미있엉'

# %%
# 아무것도 리턴하지 않는 경우
def oz_return():
    return

result= oz_return()
print(result)

oz_return()
# Out:
# None

# %%
bool(None)
# Out:
# False

# %%
result = input("1+1은 ?")
print(result)
# Out:
# 1+1은 ?2
# 2
