# %% [markdown]
# ### 자료형 종류
# int(integer) : 정수형
# float(float) : 실수
# str(string) : 문자
# bool(bool,boolean) : 참 또는 거짓, true 또는 false, 1또는 0
#
# ----
#
# list
# tuple
# dict
# set

# %%
# bool의 쇼타임 시작됩니다.
#  주의할 점 true x true False x false
# 부등호
3 > 1
3 == 1
3 == 3

20 != 5
20 != 20
# Out:
# False

# %%
#문자열 비교
"python" == "Python"
"Python" == "Python"
"Python" != "Python"
# Out:
# False

# %%
#부등호
5 >= 5
5<4
# Out:
# False

# %%
# 중요
#  ==, is

3 is 3
3 == 3

3.0 is 3
3.0 == 3

print(id(3.0))
print(id(3))
# Out:
# 137376010725744
# 137376239550768
# <>:4: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-19-60d638c4e5b8>:4: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   3 is 3
# <ipython-input-19-60d638c4e5b8>:7: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   3.0 is 3

# %% [markdown]
# 미션 값 비교에는 is를 쓰면 안되는데 그 이유를 찾아서 기술 블로그에 작성해 보세요

# %%
#본격적인 논리연산자
# True: 1 / False: 0
True and True # 1*1 =1
# True and False #1*0=0
# False and True #0
# False and False #0
# Out:
# True

# %%
#본격적인 논리연산자
# True: 1 / False: 0
# True or True # 1+1 =1
# True or False #1+0=1
# False or True #1
False or False #0
# Out:
# False

# %%
# not
not True
not False
# Out:
# True

# %%
#점점 복잡해지는 조건들!!!

10==12 or 6!=2 #f+t t
2>5 and 7==7 #f*t f
not 14<=15 #
not 7 is 7.0
# Out:
# <>:6: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:6: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-39-7fc0bd436184>:6: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   not 7 is 7.0
# True

# %%
#문자열?? 너 뭐야 True 트루야?
bool("힘들어요 여러분여러분여러분여러분")
# Out:
# True

# %%
#굉장히 중요한 내용
#단락 평가
print(False and True)
print(False and "힘들어요")

print(True and False)

print(True and '힘들어요') # 1*1,0
# Out:
# False
# False
# False
# 힘들어요
