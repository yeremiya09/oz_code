# %%
number = input("숫자를 입력해주세요")
number = int(number)

if number>0:
    raise NotImplementedError
else:
    raise NotImplementedError
# Out:
# 숫자를 입력해주세요10
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-1-fdd21bf53697> in <cell line: 4>()
#       3
#       4 if number>0:
# ----> 5     raise NotImplementedError
#       6 else:
#       7     raise NotImplementedError
#
# NotImplementedError:
