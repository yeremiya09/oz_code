# %%
def oz():
    for i in range(5):
        print ("oz코딩스쿨")

oz()
# Out:
# oz코딩스쿨
# oz코딩스쿨
# oz코딩스쿨
# oz코딩스쿨
# oz코딩스쿨

# %%
print('어떤가요 이것도 할 수 있어요')
# Out:
# 어떤가요 이것도 할 수 있어요

# %%
def 함수이름(매개변수,매개변수)
    코드

# %%
def oz(message, n):
    for i in range(n):
        print(message)

oz('oz코딩스쿨', 5)
# Out:
# oz코딩스쿨
# oz코딩스쿨
# oz코딩스쿨
# oz코딩스쿨
# oz코딩스쿨

# %%
def oz(message, n):
    for i in range(n):
        print(message)

oz('oz코딩스쿨', 5)

# def oz(message, 5):
#     for i in range(5):
#         print(message)

# oz('oz코딩스쿨', 5)
