# %%
def oz():
    print("파이썬 진짜 재미있엉 하하")

oz()
# Out:
# 파이썬 진짜 재미있엉 하하

# %%
def test(function):
    def wrapper():
        print("함수 시작")
        function()
        print("함수 끝")
    return wrapper

@test
def oz():
    print("파이썬 진짜 재미있엉 하하")

oz()
# Out:
# 함수 시작
# 파이썬 진짜 재미있엉 하하
# 함수 끝
