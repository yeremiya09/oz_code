# %%
# 구문오류
print("오류는 아주 사소한 것부터 발생합니다"
# Out:
#   File "<ipython-input-1-5fb863b36899>", line 2
#     print("오류는 아주 사소한 것부터 발생합니다"
#                                 ^
# SyntaxError: incomplete input

# %%
print("오류는 아주 사소한 것부터 발생합니다")

dogs.append("말티즈")
# Out:
# 오류는 아주 사소한 것부터 발생합니다
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aeefff6e1282> in <cell line: 3>()
#       1 print("오류는 아주 사소한 것부터 발생합니다")
#       2
# ----> 3 dogs.append("말티즈")
#
# NameError: name 'dogs' is not defined

# %%
print("오류는 아주 사소한 것부터 발생합니다")

dogs = ["닥스훈트", "시바견"]
dogs.append("말티즈")
print(dogs)
# Out:
# 오류는 아주 사소한 것부터 발생합니다
# ['닥스훈트', '시바견', '말티즈']

# %%
x, y = map(int, input("밑변과 높이를 입력하세요").split())

print(f'삼각형의 넓이는 {x*y/2} 입니다')
# Out:
# 밑변과 높이를 입력하세요10 10
# 삼각형의 넓이는 50.0 입니다

# %%
# x = 3cm, y = 5cm
x, y = map(int, input("밑변과 높이를 입력하세요").split())

print(f'삼각형의 넓이는 {x*y/2} 입니다')
# Out:
# 밑변과 높이를 입력하세요3 5
# 삼각형의 넓이는 7.5 입니다

# %%
from genericpath import isdir
x, y = input("밑변과 높이를 입력하세요").split()

if x.isdigit() and y.isdigit():
    x = int(x)
    y = int(y)
    print(f'삼각형의 넓이는 {x*y/2} 입니다')
else:
    print("정수로 입력하지 않아 계산이 불가합니다")
