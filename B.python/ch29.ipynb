# %%
oz_tuple = (1, 2, 3)

print(oz_tuple)
print(oz_tuple[0])
print(oz_tuple[1])
print(oz_tuple[2])
# Out:
# (1, 2, 3)
# 1
# 2
# 3

# %%
oz_tuple[2] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-981abcf0aec2> in <cell line: 1>()
# ----> 1 oz_tuple[2] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
oz_tuple = 1, 2, 3, 4

print("oz_tuple: ", oz_tuple)
print("oz_tuple_type: ", type(oz_tuple))
# Out:
# oz_tuple:  (1, 2, 3, 4)
# oz_tuple_type:  <class 'tuple'>

# %%
x, y, z= 1, 2, 3

print("x: ", x)
print("y: ", y)
print("z: ", z)
# Out:
# x:  1
# y:  2
# z:  3

# %%
x, y = 1, 2

print("x: ", x)
print("y: ", y)
print()

x, y = y, x
print("x: ", x)
print("y: ", y)
# Out:
# x:  1
# y:  2
#
# x:  2
# y:  1

# %%
def oz_tuple():
    return (1, 2)

x, y = oz_tuple()

print("x: ", x)
print("y: ", y)
# Out:
# x:  1
# y:  2

# %%
for i, fruit in enumerate(["apple", "banana", "cherry"]):
    print(i, fruit)
# Out:
# 0 apple
# 1 banana
# 2 cherry

# %%
a, b = 7, 3
x, y = divmod(a, b)

print("몫: ", x)
print("나머지: ", y)
# Out:
# 몫:  2
# 나머지:  1
